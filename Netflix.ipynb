# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %%
data = pd.read_csv('netflix.csv')

# %%
data.isnull().sum()
data.fillna(0,inplace=True)

# %%
data['duration'] = data['duration'].str.replace(' min','')
data['duration'] = data['duration'].str.replace(' Seasons','')
data['duration'] = data['duration'].str.replace(' Season','')
data['duration']
# Out:
# 0        90
# 1         2
# 2         1
# 3         1
# 4         2
#        ...
# 8802    158
# 8803      2
# 8804     88
# 8805     88
# 8806    111
# Name: duration, Length: 8807, dtype: object

# %%
data['type'].value_counts().plot(kind='bar', color=['#DC143C', '#B22222'])
plt.title('TV Shows vs Movies')
plt.show()

# %%
data.groupby('release_year').size().plot(kind='line', color='#B22222')
plt.title('Year-wise Content Release')
plt.show()

# %%
top_countries = data['country'].value_counts().head(10)
top_countries.plot(kind='bar', color=['#DC143C', '#B22222', '#DC143C', '#B22222', '#DC143C', '#B22222', '#DC143C', '#B22222', '#DC143C', '#B22222'])
plt.title('Top 10 Countries with Most Content')
plt.show()

# %%
data['listed_in'] = data['listed_in'].str.split(',')
exploded_genres = data.explode('listed_in')
top_genres = exploded_genres['listed_in'].value_counts().head(10)
top_genres.plot(kind='bar', color=['#DC143C', '#B22222', '#DC143C', '#B22222', '#DC143C', '#B22222', '#DC143C', '#B22222', '#DC143C', '#B22222'])
plt.title('Top Genres')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-57-311ca43b6dd1> in <cell line: 4>()
#       2 exploded_genres = data.explode('listed_in')
#       3 top_genres = exploded_genres['listed_in'].value_counts().head(10)
# ----> 4 top_genres.plot(kind='bar', color=['#DC143C', '#B22222', '#DC143C', '#B22222', '#DC143C', '#B22222', '#DC143C', '#B22222', '#DC143C', '#B22222'])
#       5 plt.title('Top Genres')
#       6 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#    1029                     data.columns = label_name
#    1030
# -> 1031         return plot_backend.plot(data, kind=kind, **kwargs)
#    1032
#    1033     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
# ...

# %%
data['rating'].value_counts().plot(kind='bar', color=['#DC143C', '#B22222', '#DC143C', '#B22222', '#DC143C', '#B22222', '#DC143C', '#B22222', '#DC143C', '#B22222'])
plt.title('Distribution of Content Ratings')
plt.show()
